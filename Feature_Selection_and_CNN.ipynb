# %% [markdown]
# <a href="https://colab.research.google.com/github/nikilstark/santander-customer-satisfaction/blob/master/Feature_Selection_and_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-gpu==2.0.0-rc0
# Out:
# ...
#      |████████████████████████████████| 380.5MB 40kB/s
# ...
#      |████████████████████████████████| 4.3MB 44.2MB/s
# ...
#      |████████████████████████████████| 501kB 45.6MB/s
# ...

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv1D,MaxPool1D,Flatten,Dense,Dropout,BatchNormalization
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold

# %%
from tensorflow.keras.optimizers import Adam

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c santander-customer-satisfaction

# %%
df_train = pd.read_csv('/content/train.csv.zip')

# %%
df_test = pd.read_csv('/content/test.csv.zip')

# %%
df_test.head(5)
# Out:
#    ID  var3  var15  ...  saldo_medio_var44_ult1  saldo_medio_var44_ult3      var38
# 0   2     2     32  ...                     0.0                     0.0   40532.10
# 1   5     2     35  ...                     0.0                     0.0   45486.72
# 2   6     2     23  ...                     0.0                     0.0   46993.95
# 3   7     2     24  ...                     0.0                     0.0  187898.61
# 4   9     2     23  ...                     0.0                     0.0   73649.73
#
# [5 rows x 370 columns]

# %%
df_train.head(5)
# Out:
#    ID  var3  var15  ...  saldo_medio_var44_ult3          var38  TARGET
# 0   1     2     23  ...                     0.0   39205.170000       0
# 1   3     2     34  ...                     0.0   49278.030000       0
# 2   4     2     23  ...                     0.0   67333.770000       0
# 3   8     2     37  ...                     0.0   64007.970000       0
# 4  10     2     39  ...                     0.0  117310.979016       0
#
# [5 rows x 371 columns]

# %%
df_train.shape
# Out:
# (76020, 371)

# %%
x = df_train.drop(labels=['ID','TARGET'],axis=1)
x.shape
# Out:
# (76020, 369)

# %%
y= df_train["TARGET"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 4 , stratify = y)

# %%
x_train.shape,x_test.shape
# Out:
# ((60816, 369), (15204, 369))

# %%
filter = VarianceThreshold(0.01)
x_train = filter.fit_transform(x_train)
x_test = filter.transform(x_test)

# %%
x_train_T =x_train.T
x_test_T = x_test.T

# %%
x_train_T = pd.DataFrame(x_train_T)
x_test_T = pd.DataFrame(x_test_T)

# %%
x_train_T.shape
# Out:
# (270, 60816)

# %%
x_train_T.duplicated().sum()
# Out:
# 17

# %%
duplicated_features = x_train_T.duplicated()
duplicated_features
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 265    False
# 266    False
# 267    False
# 268    False
# 269    False
# Length: 270, dtype: bool

# %%
features_selected = [not index for index in duplicated_features]

# %%
x_train_f = x_train_T[features_selected].T 
x_train_f.shape
# Out:
#        0     1    2       3       4    ...  265  266  267  268            269
# 0      2.0  23.0  0.0    0.00    0.00  ...  0.0  0.0  0.0  0.0  104498.490000
# 1      2.0  23.0  0.0    0.00    0.00  ...  0.0  0.0  0.0  0.0  117310.979016
# 2      2.0  23.0  0.0    0.00    0.00  ...  0.0  0.0  0.0  0.0  117310.979016
# 3      2.0  28.0  0.0    0.00    0.00  ...  0.0  0.0  0.0  0.0  258491.040000
# 4      2.0  35.0  0.0  681.51  681.51  ...  0.0  0.0  0.0  0.0  777488.640000
# ...    ...   ...  ...     ...     ...  ...  ...  ...  ...  ...            ...
# 60811  2.0  40.0  0.0    0.00    0.00  ...  0.0  0.0  0.0  0.0  180903.960000
# 60812  2.0  23.0  0.0    0.00    0.00  ...  0.0  0.0  0.0  0.0   84960.450000
# 60813  2.0  22.0  0.0    0.00    0.00  ...  0.0  0.0  0.0  0.0  107983.230000
# 60814  2.0  50.0  0.0    0.00    0.00  ...  0.0  0.0  0.0  0.0  117310.979016
# 60815  2.0  29.0  0.0    0.00    0.00  ...  0.0  0.0  0.0  0.0  278681.010000
#
# [60816 rows x 253 columns]

# %%
x_test_f = x_test_T[features_selected].T 
x_test_f.shape
# Out:
# (15204, 253)

# %%
scaler =StandardScaler()
x_train_f = scaler.fit_transform(x_train_f)
x_test_f = scaler.transform(x_test_f)

# %%
x_train_f.shape,x_test_f.shape
# Out:
# ((60816, 253), (15204, 253))

# %%
x_train_f =  x_train_f.reshape(60816,253,1)
x_test_f = x_test_f.reshape(15204,253,1)

# %%
y_train =y_train.to_numpy()
y_test =y_test.to_numpy()

# %%
model =Sequential()
model.add(Conv1D(filters=32,kernel_size=3,activation='relu',input_shape =(253,1)))
model.add(BatchNormalization())
model.add(MaxPool1D(pool_size=2))
model.add(Dropout(0.3))

model.add(Conv1D(filters=64,kernel_size=3,activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool1D(pool_size=2))
model.add(Dropout(0.5))

model.add(Conv1D(filters=128,kernel_size=3,activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool1D(pool_size=2))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(253,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d (Conv1D)              (None, 251, 32)           128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 251, 32)           128
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 125, 32)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 125, 32)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 123, 64)           6208
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 123, 64)           256
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 61, 64)            0
# ...

# %%
model.compile(optimizer=Adam(lr = 0.00005),loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train_f,y_train,epochs=10,validation_data=(x_test_f,y_test),verbose=1)
# Out:
# Train on 60816 samples, validate on 15204 samples
# Epoch 1/10
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 60816/60816 [==============================] - 112s 2ms/sample - loss: 0.2250 - accuracy: 0.9526 - val_loss: 0.1886 - val_accuracy: 0.9597
# Epoch 2/10
# 60816/60816 [==============================] - 110s 2ms/sample - loss: 0.1783 - accuracy: 0.9591 - val_loss: 0.1841 - val_accuracy: 0.9599
# Epoch 3/10
# 60816/60816 [==============================] - 110s 2ms/sample - loss: 0.1685 - accuracy: 0.9602 - val_loss: 0.1832 - val_accuracy: 0.9593
# Epoch 4/10
# 60816/60816 [==============================] - 109s 2ms/sample - loss: 0.1660 - accuracy: 0.9602 - val_loss: 0.1839 - val_accuracy: 0.9600
# Epoch 5/10
# ...

# %%
def plot_learningcurve(history,epochs):
  epoch_range = range(1,epochs+1)
  plt.plot(epoch_range,history.history['accuracy'])
  plt.plot(epoch_range,history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train','val'],loc='upper left')
  plt.show()

  plt.plot(epoch_range,history.history['loss'])
  plt.plot(epoch_range,history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train','val'],loc='upper left')
  plt.show()

# %%
plot_learningcurve(history,10)
